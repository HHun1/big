# %% [markdown]
# <a href="https://colab.research.google.com/github/HHun1/big/blob/main_7/lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = './stores-dist.csv'
df_main = pd.read_csv(file)
df_main.head()
# Out:
#    district  annual net sales  number of stores in district
# 0         1             231.0                            12
# 1         2             156.0                            13
# 2         3              10.0                            16
# 3         4             519.0                             2
# 4         5             437.0                             6

# %%
df_main = df_main.rename(columns={'annual net sales':'sales',
                                  'number of stores in district':'stores'})
df_main.head()
# Out:
#    district  sales  stores
# 0         1  231.0      12
# 1         2  156.0      13
# 2         3   10.0      16
# 3         4  519.0       2
# 4         5  437.0       6

# %% [markdown]
# Part 2

# %%
df_corr = df_main.corr()
df_corr
# Out:
#           district     sales    stores
# district  1.000000  0.136103 -0.230617
# sales     0.136103  1.000000 -0.912236
# stores   -0.230617 -0.912236  1.000000

# %%
df = df_main.drop('district', axis=1)
df.head()
# Out:
#    sales  stores
# 0  231.0      12
# 1  156.0      13
# 2   10.0      16
# 3  519.0       2
# 4  437.0       6

# %%
y = df['sales']
x = df.stores

# %%
# %matplotlib inline

plt.figure(figsize = (20,10))
plt.plot(x,y,'o',markersize=30)
plt.ylabel('Annual Net Sales', fontsize = 30)
plt.xlabel('Number of Stores in the District', fontsize = 30)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

plt.show()

# %% [markdown]
# Part 3

# %%
m,b = np.polyfit(x,y,1)
print('The slope of line is {:.2f}.'.format(m))
print('The y-inetcept is {:.2f}.'.format(b))
print('The besst fit =simple linear regression line is {:.2}x + {:.2f}'.format(m,b))
# Out:
# The slope of line is -35.79.
# The y-inetcept is 599.38.
# The besst fit =simple linear regression line is -3.6e+01x + 599.38

# %%
y_mean = y.mean()
x_mean = x.mean()
print('The centroid for this dataset is x = {:.2f} and y = {:.2f}'.format(x_mean,y_mean))
# Out:
# The centroid for this dataset is x = 8.74 and y = 286.57

# %%
# %matplotlib inline
plt.figure(figsize=(15,10))
plt.plot(x,y,'o',markersize = 14, label = 'Annual Net Sales')
plt.plot(x_mean,y_mean, '*', markersize = 30, color = 'r')
plt.plot(x, m*x+b, '-', label = 'Simple Linear Regression Line', linewidth = 4)
plt.ylabel('Annual Net Sales', fontsize = 30)
plt.xlabel('Number of Stores ifn District', fontsize = 30)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.annotate('Centroid', xy=(x_mean-0.1,y_mean-5),xytext=(x_mean-3,y_mean-20), arrowprops=dict(facecolor='black',shrink=0.05),fontsize=30)
plt.legend(loc = 'upper right', fontsize = 20)

# %%
def predict(query):
    if query >=1:
        predict = m*query+b
        return predict
    else:
        print('You must have at least 1 store in the district to pedict the annual net sales.')

# %%
predict(10)
# Out:
# 241.50885534292138

# %%
predict(4)
# Out:
# 456.2313681207654
